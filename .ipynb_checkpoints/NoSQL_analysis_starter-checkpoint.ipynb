# %% [markdown]
# # Eat Safe, Love

# %% [markdown]
# ## Notebook Set Up

# %%
from pymongo import MongoClient
import pandas as pd
from pprint import pprint

# %%
# Create an instance of MongoClient
mongo = MongoClient(port=27017)

# %%
# assign the uk_food database to a variable name
db = mongo['uk_food']

# %%
# review the collections in our database
collections = db.list_collection_names()
collections
# Out:
# ['establishments']

# %%
# assign the collection to a variable
establishments = db['establishments']

# %% [markdown]
# ## Part 3: Exploratory Analysis
# Unless otherwise stated, for each question:
# * Use `count_documents` to display the number of documents contained in the result.
# * Display the first document in the results using `pprint`.
# * Convert the result to a Pandas DataFrame, print the number of rows in the DataFrame, and display the first 10 rows.

# %% [markdown]
# ### 1. Which establishments have a hygiene score equal to 20?

# %%
# Find the establishments with a hygiene score of 20
query = {'scores.Hygiene': 20}

# Use count_documents to display the number of documents in the result
count = establishments.count_documents(query)
print(f"Number of establishments with a hygiene score of 20: {count}")

# Display the first document in the results using pprint
first_document = establishments.find_one(query)
print("First document with a hygiene score of 20:")
pprint(first_document)
# Out:
# Number of establishments with a hygiene score of 20: 41
# First document with a hygiene score of 20:
# {'AddressLine1': '5-6 Southfields Road',
#  'AddressLine2': 'Eastbourne',
#  'AddressLine3': 'East Sussex',
#  'AddressLine4': '',
#  'BusinessName': 'The Chase Rest Home',
#  'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  'ChangesByServerID': 0,
#  'Distance': 4613.888288172291,
#  'FHRSID': 110681,
#  'LocalAuthorityBusinessID': '4029',
#  'LocalAuthorityCode': '102',
#  'LocalAuthorityEmailAddress': 'Customerfirst@eastbourne.gov.uk',
#  'LocalAuthorityName': 'Eastbourne',
#  'LocalAuthorityWebSite': 'http://www.eastbourne.gov.uk/foodratings',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'BN21 1BU',
#  'RatingDate': '2021-09-23T00:00:00',
#  'RatingKey': 'fhrs_0_en-gb',
#  'RatingValue': None,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('66db734f04ecce12e250bd8a'),
#  'geocode': {'latitude': 50.769705, 'longitude': 0.27694},
# ...

# %%
# Convert the result to a Pandas DataFrame
query = {'scores.Hygiene': 20}

documents = list(establishments.find(query))

df = pd.DataFrame(documents)

# Display the number of rows in the DataFrame
print(f"Number of rows in the DataFrame: {len(df)}")

# Display the first 10 rows of the DataFrame
print("First 10 rows of the DataFrame:")
print(df.head(10))
# Out:
# Number of rows in the DataFrame: 41
# First 10 rows of the DataFrame:
#                         _id   FHRSID  ChangesByServerID  \
# 0  66db734f04ecce12e250bd8a   110681                  0
# 1  66db735004ecce12e250c10b   612039                  0
# 2  66db735004ecce12e250c415   730933                  0
# 3  66db735004ecce12e250c603   172735                  0
# 4  66db735004ecce12e250c612   172953                  0
# 5  66db735104ecce12e250cfb1   512854                  0
# 6  66db735104ecce12e250d1d2  1537089                  0
# 7  66db735304ecce12e250e6fd   155648                  0
# 8  66db735304ecce12e250eb41  1012883                  0
# 9  66db735404ecce12e250f353   644109                  0
#
#   LocalAuthorityBusinessID               BusinessName  \
# 0                     4029        The Chase Rest Home
# 1                1970/FOOD                 Brenalwood
# 2                1698/FOOD              Melrose Hotel
# 3             PI/000023858              Seaford Pizza
# ...

# %%
df
# Out:
#                          _id   FHRSID  ChangesByServerID  \
# 0   66db734f04ecce12e250bd8a   110681                  0
# 1   66db735004ecce12e250c10b   612039                  0
# 2   66db735004ecce12e250c415   730933                  0
# 3   66db735004ecce12e250c603   172735                  0
# 4   66db735004ecce12e250c612   172953                  0
# 5   66db735104ecce12e250cfb1   512854                  0
# 6   66db735104ecce12e250d1d2  1537089                  0
# 7   66db735304ecce12e250e6fd   155648                  0
# 8   66db735304ecce12e250eb41  1012883                  0
# 9   66db735404ecce12e250f353   644109                  0
# 10  66db735404ecce12e250f3c3   267034                  0
# 11  66db735404ecce12e250fa79   972876                  0
# 12  66db735504ecce12e2510347  1417416                  0
# 13  66db735604ecce12e2510955  1384371                  0
# 14  66db735604ecce12e2510cb1   907216                  0
# ...

# %%
df.head(10)
# Out:
#                         _id   FHRSID  ChangesByServerID  \
# 0  66db734f04ecce12e250bd8a   110681                  0
# 1  66db735004ecce12e250c10b   612039                  0
# 2  66db735004ecce12e250c415   730933                  0
# 3  66db735004ecce12e250c603   172735                  0
# 4  66db735004ecce12e250c612   172953                  0
# 5  66db735104ecce12e250cfb1   512854                  0
# 6  66db735104ecce12e250d1d2  1537089                  0
# 7  66db735304ecce12e250e6fd   155648                  0
# 8  66db735304ecce12e250eb41  1012883                  0
# 9  66db735404ecce12e250f353   644109                  0
#
#   LocalAuthorityBusinessID               BusinessName  \
# 0                     4029        The Chase Rest Home
# 1                1970/FOOD                 Brenalwood
# 2                1698/FOOD              Melrose Hotel
# 3             PI/000023858              Seaford Pizza
# 4             PI/000024532              Golden Palace
# ...

# %% [markdown]
# ### 2. Which establishments in London have a `RatingValue` greater than or equal to 4?

# %%
# Find the establishments with London as the Local Authority and has a RatingValue greater than or equal to 4.
query = {
    'LocalAuthorityName': 'London',
    'RatingValue': {'$gte': 4}
}

documents = list(establishments.find(query))

london_4_df = pd.DataFrame(documents)

# Display the number of rows in the DataFrame
print(f"Number of rows in the DataFrame: {len(london_4_df)}")

# Display the first 10 rows of the DataFrame
print("First 10 rows of the DataFrame:")
print(london_4_df.head(10))
# Out:
# Number of rows in the DataFrame: 0
# First 10 rows of the DataFrame:
# Empty DataFrame
# Columns: []
# Index: []

# %%
# Convert the result to a Pandas DataFrame
london_4_df

# Display the number of rows in the DataFrame
print(f"Number of rows in the DataFrame: {len(london_4_df)}")

# Display the first 10 rows of the DataFrame
print("First 10 rows of the DataFrame:")
print(london_4_df.head(10))
# Out:
# Number of rows in the DataFrame: 0
# First 10 rows of the DataFrame:
# Empty DataFrame
# Columns: []
# Index: []

# %%
london_4_df
#Empty dataframe. No restaurant matches the query criteria.
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ### 3. What are the top 5 establishments with a `RatingValue` rating value of 5, sorted by lowest hygiene score, nearest to the new restaurant added, "Penang Flavours"?

# %%
# Search within 0.01 degree on either side of the latitude and longitude.
# Rating value must equal 5
# Sort by hygiene score

degree_search = 0.01
latitude = 51.152225
longitude = 0

min_lat = latitude - degree_search
max_lat = latitude + degree_search
min_lon = longitude - degree_search
max_lon = longitude + degree_search

query = {
    'RatingValue': 5,
    'geocode.latitude': {'$gte': min_lat, '$lte': max_lat},
    'geocode.longitude': {'$gte': min_lon, '$lte': max_lon}
}

sort = [('scores.Hygiene', 1)]

limit = 5

# Print the results
results = establishments.find(query).sort(sort).limit(limit)

rating_hygeine_5 = pd.DataFrame(results)
#for document in results:
#    print(document)

rating_hygeine_5
# Out:
#                         _id  FHRSID  ChangesByServerID  \
# 0  66db735404ecce12e250f693  926617                  0
# 1  66db735404ecce12e250f6aa  105158                  0
# 2  66db735404ecce12e250f6c9  105132                  0
#
#   LocalAuthorityBusinessID                             BusinessName  \
# 0                   100472                        Choice Lunch Club
# 1                    36067  Dormansland Village Preschool Playgroup
# 2                    36049                        The Village Store
#
#               BusinessType  BusinessTypeID                AddressLine1  \
# 0  Restaurant/Cafe/Canteen               1  Dormansland Baptist Church
# 1          Caring Premises               5                 Parish Room
# 2        Retailers - other            4613
#
#         AddressLine2 AddressLine3  ...         LocalAuthorityWebSite  \
# 0      7 High Street               ...  http://www.tandridge.gov.uk/
# ...

# %%
# Convert result to Pandas DataFrame

rating_hygeine_5['RatingValue']
# Out:
# 0    5
# 1    5
# 2    5
# Name: RatingValue, dtype: int64

# %% [markdown]
# ### 4. How many establishments in each Local Authority area have a hygiene score of 0?

# %%
# Create a pipeline that:
# 1. Matches establishments with a hygiene score of 0
# 2. Groups the matches by Local Authority
# 3. Sorts the matches from highest to lowest

pipeline = [
    # 1. Match establishments with a hygiene score of 0
    {"$match": {"scores.Hygiene": 0}},
    
    # 2. Group by Local Authority and count the number of establishments
    {"$group": {
        "_id": "$LocalAuthorityName",
        "count": {"$sum": 1}
    }},
    
    # 3. Sort the results by the count (highest to lowest)
    {"$sort": {"count": -1}}
]

result = list(establishments.aggregate(pipeline))

# Print the number of documents in the result

print(f"Number of documents in the result: {len(result)}")

# Print the first 10 results

pprint(result[:10])
# Out:
# Number of documents in the result: 56
# [{'_id': 'Thanet', 'count': 1130},
#  {'_id': 'Greenwich', 'count': 882},
#  {'_id': 'Maidstone', 'count': 713},
#  {'_id': 'Newham', 'count': 711},
#  {'_id': 'Swale', 'count': 686},
#  {'_id': 'Chelmsford', 'count': 680},
#  {'_id': 'Medway', 'count': 672},
#  {'_id': 'Bexley', 'count': 607},
#  {'_id': 'Southend-On-Sea', 'count': 586},
#  {'_id': 'Tendring', 'count': 542}]

# %%
# Convert the result to a Pandas DataFrame

hygeine_0 = pd.DataFrame(result)

#Rename to LocalAuthorityName
hygeine_0 = hygeine_0.rename(columns={'_id': 'LocalAuthorityName'})

# Display the number of rows in the DataFrame

print(f"Number of rows in the DataFrame: {len(hygeine_0)}")

# Display the first 10 rows of the DataFrame

print("First 10 rows of the DataFrame:")
print(hygeine_0.head(10))
# Out:
# Number of rows in the DataFrame: 56
# First 10 rows of the DataFrame:
#   LocalAuthorityName  count
# 0             Thanet   1130
# 1          Greenwich    882
# 2          Maidstone    713
# 3             Newham    711
# 4              Swale    686
# 5         Chelmsford    680
# 6             Medway    672
# 7             Bexley    607
# 8    Southend-On-Sea    586
# 9           Tendring    542

# %%
hygeine_0
# Out:
#             LocalAuthorityName  count
# 0                       Thanet   1130
# 1                    Greenwich    882
# 2                    Maidstone    713
# 3                       Newham    711
# 4                        Swale    686
# 5                   Chelmsford    680
# 6                       Medway    672
# 7                       Bexley    607
# 8              Southend-On-Sea    586
# 9                     Tendring    542
# 10                  Colchester    498
# 11             Tunbridge Wells    491
# 12        Folkestone and Hythe    480
# 13                  Eastbourne    478
# 14                    Hastings    464
# 15                     Bromley    460
# 16                     Ashford    427
# 17                    Havering    397
# 18                    Dartford    383
# 19                   Braintree    382
# 20                    Basildon    362
# 21                   Gravesham    339
# 22       Tonbridge and Malling    325
# 23                    Thurrock    313
# ...
